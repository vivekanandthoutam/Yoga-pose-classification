# %%
import pandas as pd 
from numpy import array
import numpy as np

# %%
df=pd.read_csv("/content/sample_data/angles_Shiva_Vriksh.csv")

# %%
del df['Unnamed: 0']

# %%
df=df.iloc[:,0:12]

# %%
avg_arr=[]
for i in range(df.shape[1]):
  avg=0
  for j in range(df.shape[0]):
      avg=avg+df.iloc[j:j+1,i:i+1].to_numpy()[0][0]
  avg=avg/df.shape[0]    
  avg_arr.append(avg)

# %%
avg_arr
# Out:
# [177.1818181818182,
#  245.21818181818182,
#  20.236363636363638,
#  357.6909090909091,
#  290.25454545454545,
#  155.56363636363636,
#  249.0,
#  218.6727272727273,
#  327.1454545454545,
#  274.4909090909091,
#  258.90909090909093,
#  258.6545454545454]

# %%
df
# Out:
#     [0,2]  [2,4]  [4,6]  [0,8]  ...  [16,18]  [0,20]  [20,22]  [22,24]
# 0     180    240      8    361  ...      331     271      258      260
# 1     180    242      9    360  ...      332     272      258      261
# 2     177    242      8    358  ...      332     270      258      261
# 3     174    240      5    357  ...      331     269      258      260
# 4     178    240      6    360  ...      331     271      258      261
# 5     176    237     11    356  ...      325     273      258      259
# 6     175    237     10    356  ...      325     272      258      259
# 7     175    236     10    355  ...      325     272      258      259
# 8     175    236     11    356  ...      324     272      259      260
# 9     175    241     12    356  ...      325     274      258      259
# 10    176    245     17    356  ...      324     272      260      256
# 11    180    245     17    360  ...      324     274      261      256
# ...
